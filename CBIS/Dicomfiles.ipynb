# %% [markdown]
# # Import

# %%
import csv
import pandas as pd
import numpy as np

# %% [markdown]
# # Load dataframe

# %%
path = "E:/Dataset/Mammography/3/mass_case_description_test_set.csv"
path2 = "E:/Dataset/Mammography/3/mass_case_description_train_set.csv"
df = pd.read_csv(path)
df2 = pd.read_csv(path2)
df
# Out:
#     patient_id  breast_density left or right breast image view  \
# 0      P_00016               4                 LEFT         CC
# 1      P_00016               4                 LEFT        MLO
# 2      P_00017               2                 LEFT         CC
# 3      P_00017               2                 LEFT        MLO
# 4      P_00032               3                RIGHT         CC
# ..         ...             ...                  ...        ...
# 373    P_01825               2                RIGHT        MLO
# 374    P_01833               2                RIGHT        MLO
# 375    P_01865               2                 LEFT        MLO
# 376    P_01912               3                RIGHT         CC
# 377    P_01912               3                RIGHT        MLO
#
#      abnormality id abnormality type mass shape    mass margins  assessment  \
# 0                 1             mass  IRREGULAR      SPICULATED           5
# ...

# %%
np.unique(df["breast_density"])
# Out:
# array([1, 2, 3, 4], dtype=int64)

# %%
len(df["breast_density"])
# Out:
# 378

# %%
 # dataset de treino
((len(df[df['breast_density'] == 1]),len(df[df['breast_density'] == 2]),
 len(df[df['breast_density'] == 3]),len(df[df['breast_density'] == 4])),
 #dataset de teste
(len(df2[df2['breast_density'] == 1]),len(df2[df2['breast_density'] == 2]),
 len(df2[df2['breast_density'] == 3]),len(df2[df2['breast_density'] == 4])),
 #total
 (len(df[df['breast_density'] == 1])+len(df2[df2['breast_density'] == 1]),len(df[df['breast_density'] == 2])+len(df2[df2['breast_density'] == 2]),
 len(df[df['breast_density'] == 3])+len(df2[df2['breast_density'] == 3]),len(df[df['breast_density'] == 4])+len(df2[df2['breast_density'] == 4])))
# Out:
# ((50, 172, 112, 44), (287, 585, 337, 109), (337, 757, 449, 153))

# %%
df[df['pathology'] != "MALIGNANT"]
# Out:
#     patient_id  breast_density left or right breast image view  \
# 4      P_00032               3                RIGHT         CC
# 5      P_00032               3                RIGHT        MLO
# 8      P_00056               3                 LEFT        MLO
# 11     P_00099               2                 LEFT        MLO
# 12     P_00114               3                 LEFT        MLO
# ..         ...             ...                  ...        ...
# 365    P_01797               2                 LEFT        MLO
# 368    P_01800               4                RIGHT         CC
# 369    P_01807               3                RIGHT        MLO
# 372    P_01825               2                RIGHT         CC
# 373    P_01825               2                RIGHT        MLO
#
#      abnormality id abnormality type                          mass shape  \
# 4                 1             mass                               ROUND
# ...

# %%
df2[df2['pathology'] != "MALIGNANT"]
# Out:
#      patient_id  breast_density left or right breast image view  \
# 2       P_00004               3                 LEFT         CC
# 3       P_00004               3                 LEFT        MLO
# 4       P_00004               3                RIGHT        MLO
# 8       P_00018               2                RIGHT         CC
# 9       P_00018               2                RIGHT        MLO
# ...         ...             ...                  ...        ...
# 1299    P_01886               3                RIGHT         CC
# 1300    P_01887               2                 LEFT         CC
# 1301    P_01887               2                 LEFT        MLO
# 1303    P_01889               1                RIGHT         CC
# 1304    P_01889               1                RIGHT        MLO
#
#       abnormality id abnormality type                mass shape  \
# 2                  1             mass  ARCHITECTURAL_DISTORTION
# 3                  1             mass  ARCHITECTURAL_DISTORTION
# ...

# %%
df2[df2['subtlety']== 5]
# Out:
#      patient_id  breast_density left or right breast image view  \
# 4       P_00004               3                RIGHT        MLO
# 8       P_00018               2                RIGHT         CC
# 9       P_00018               2                RIGHT        MLO
# 10      P_00021               1                 LEFT         CC
# 11      P_00021               1                 LEFT        MLO
# ...         ...             ...                  ...        ...
# 1309    P_01981               2                RIGHT         CC
# 1310    P_01981               2                RIGHT        MLO
# 1311    P_01983               2                 LEFT        MLO
# 1314    P_02079               2                RIGHT         CC
# 1315    P_02079               2                RIGHT        MLO
#
#       abnormality id abnormality type mass shape   mass margins  assessment  \
# 4                  1             mass       OVAL  CIRCUMSCRIBED           4
# ...

# %%
df[df['patient_id']== "P_00370"]
# Out:
# Empty DataFrame
# Columns: [patient_id, breast_density, left or right breast, image view, abnormality id, abnormality type, mass shape, mass margins, assessment, pathology, subtlety, image file path, cropped image file path, ROI mask file path]
# Index: []

# %%
df2[(df2['mass margins'] == "ILL_DEFINED") & (df2['pathology']== "MALIGNANT")]
# Out:
#      patient_id  breast_density left or right breast image view  \
# 5       P_00009               3                RIGHT         CC
# 6       P_00009               3                RIGHT        MLO
# 32      P_00045               4                 LEFT         CC
# 33      P_00045               4                 LEFT        MLO
# 41      P_00058               2                RIGHT         CC
# ...         ...             ...                  ...        ...
# 1306    P_01908               2                 LEFT         CC
# 1309    P_01981               2                RIGHT         CC
# 1310    P_01981               2                RIGHT        MLO
# 1312    P_02033               2                RIGHT         CC
# 1313    P_02033               2                RIGHT        MLO
#
#       abnormality id abnormality type                mass shape mass margins  \
# 5                  1             mass                      OVAL  ILL_DEFINED
# ...

# %%
np.unique(df['pathology'])
# Out:
# array(['BENIGN', 'BENIGN_WITHOUT_CALLBACK', 'MALIGNANT'], dtype=object)
